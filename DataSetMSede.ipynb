# %%
import pandas as pd

# %%
convertir = pd.read_excel('m_sede.xlsx')

# %%
convertir.to_csv('estudiantes.csv', index=None, header=True)

# %%
df = pd.read_csv('estudiantes.csv')

# %%
df
# Out:
#    idM_sede        Ident         nombre codigo          Ciudad  \
# 0        11   9000754561  Asignar S.A.S    MDN        Medellin
# 1        12   9000754562  Asignar S.A.S    BOG          Bogota
# 2        13   9000754563  Asignar S.A.S    SAN      San Andres
# 3        14   9000754564  Asignar S.A.S    CAL            Cali
# 4        15   9000754565  Asignar S.A.S    ADM  Administracion
# 5        16   9000754566  Asignar S.A.S    BRQ    Barranquilla
# 6        17   9000754567  Asignar S.A.S    RIO        Rionegro
# 7        18   9000754568  Asignar S.A.S    PER         Pereira
# 8        19  90007545613  Asignar S.A.S    CTG       Cartagena
#
#        Nom_Contac                        Email  \
# 0  Sandra Camacho  diroperativa@asignar.com.co
# 1   Jorge Camacho     asibogota@asignar.com.co
# 2  Sandra Camacho  diroperativa@asignar.com.co
# 3   Jorge Camacho     asibogota@asignar.com.co
# 4  Sandra Camacho  diroperativa@asignar.com.co
# 5       Pendiente                    pendiente
# 6  Sandra Camacho  diroperativa@asignar.com.co
# 7  Sandra Camacho  diroperativa@asignar.com.co
# 8  Sandra Camacho  diroperativa@asignar.com.co
#
#                                                  Dir                    Tel  \
# 0  CR 48 10-45 Oficina 925, Centro comercial Mont...  PBX (57) 604 322 0310
# 1  Cra 19 44-27 Of. 203 - Entrada vehicular: Cra ...  PBX (57) 604 322 0310
# 2                                         San Andres                      0
# 3                        Carrera 19 No 44-27 Of. 203                6091029
# 4  CR 48 10-45 Oficina 802, Centro comercial Mont...                3220310
# 5                             Calle Centro Comercial  PBX (57) 604 322 0310
# 6  CR 48 10-45 Oficina 802, Centro comercial Mont...                3220310
# 7                                            Pereira                3220310
# 8                                          Cartagena                3220310
#
#    Estado                                 Dpto
# 0       1      Medellin - Antioquia - Colombia
# 1       1     Bogota - Cundinamarca - Colombia
# 2       1                                  NaN
# 3       1                                  NaN
# 4       1                                  NaN
# 5       1  Barranquilla - Atlantico - Colombia
# 6       1                                  NaN
# 7       1                                  NaN
# 8       1                                  NaN

# %%
df.tail(3)
# Out:
#    idM_sede        Ident         nombre codigo     Ciudad      Nom_Contac  \
# 6        17   9000754567  Asignar S.A.S    RIO   Rionegro  Sandra Camacho
# 7        18   9000754568  Asignar S.A.S    PER    Pereira  Sandra Camacho
# 8        19  90007545613  Asignar S.A.S    CTG  Cartagena  Sandra Camacho
#
#                          Email  \
# 6  diroperativa@asignar.com.co
# 7  diroperativa@asignar.com.co
# 8  diroperativa@asignar.com.co
#
#                                                  Dir      Tel  Estado Dpto
# 6  CR 48 10-45 Oficina 802, Centro comercial Mont...  3220310       1  NaN
# 7                                            Pereira  3220310       1  NaN
# 8                                          Cartagena  3220310       1  NaN
