# %%
import pandas as pd

# %%
df = pd.read_csv('ModalidadVirtual.csv')

# %%
df
# Out:
#                                             Unnamed: 0        time  \
# 0                                                    0  2020-11-08
# 1                                                    1  2020-11-08
# 2    2,2020-11-08,Ingeniería de Sistemas,Si,Horario...         NaN
# 3                                                    3  2020-11-08
# 4                                                    4  2020-11-08
# ..                                                 ...         ...
# 217                                                230  2020-12-10
# 218  231,2020-12-11,Ingeniería de Sistemas,No,Acces...         NaN
# 219  232,2020-12-11,Gestión Turística y Hotelera,No...         NaN
# 220                                                233  2020-12-11
# 221  234,2020-12-12,Comercio Internacional,Si,Horar...         NaN
#
#                           carrera acepta                       positivo  \
# 0          Ingeniería de Sistemas     Si              Horario flexible.
# ...

# %%
df['carrera'][1]
# Out:
# 'Psicología'

# %%
df['edad'] > 23
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 217    False
# 218    False
# 219    False
# 220    False
# 221    False
# Name: edad, Length: 222, dtype: bool

# %%
filtrar = df['edad'] > 23

# %%
df_filtrar = df[filtrar]

# %%
df_filtrar
# Out:
#     Unnamed: 0        time                   carrera acepta  \
# 1            1  2020-11-08                Psicología     Si
# 4            4  2020-11-08    Ingeniería de Sistemas     Si
# 5            5  2020-11-08  Ciencias de la Educación     Si
# 9            9  2020-11-08    Ingeniería de Sistemas     Si
# 10          10  2020-11-08                Psicología     Si
# ..         ...         ...                       ...    ...
# 204        216  2020-12-08                      Otra     Si
# 205        217  2020-12-08    Comercio Internacional     Si
# 206        218  2020-12-08     Lingüística e Idiomas     Si
# 208        220  2020-12-08                Psicología     Si
# 216        229  2020-12-10            Trabajo Social     Si
#
#                           positivo                                negativo  \
# 1    Acceso desde cualquier lugar.  Contacto Personal Docente-Estudiantil.
# 4    Acceso desde cualquier lugar.  Contacto Personal Docente-Estudiantil.
# ...

# %%
print(df.head(10))
# Out:
#                                           Unnamed: 0        time  \
# 0                                                  0  2020-11-08
# 1                                                  1  2020-11-08
# 2  2,2020-11-08,Ingeniería de Sistemas,Si,Horario...         NaN
# 3                                                  3  2020-11-08
# 4                                                  4  2020-11-08
# 5                                                  5  2020-11-08
# 6  6,2020-11-08,Ingeniería de Sistemas,Si,Acceso ...         NaN
# 7                                                  7  2020-11-08
# 8                                                  8  2020-11-08
# 9                                                  9  2020-11-08
#
#                     carrera acepta                       positivo  \
# 0    Ingeniería de Sistemas     Si              Horario flexible.
# 1                Psicología     Si  Acceso desde cualquier lugar.
# ...

# %%
df.head(3)
# Out:
#                                           Unnamed: 0        time  \
# 0                                                  0  2020-11-08
# 1                                                  1  2020-11-08
# 2  2,2020-11-08,Ingeniería de Sistemas,Si,Horario...         NaN
#
#                   carrera acepta                       positivo  \
# 0  Ingeniería de Sistemas     Si              Horario flexible.
# 1              Psicología     Si  Acceso desde cualquier lugar.
# 2                     NaN    NaN                            NaN
#
#                                  negativo  edad    sexo   trabajo
# 0  Contacto Personal Docente-Estudiantil.  20.0  Hombre  Eventual
# 1  Contacto Personal Docente-Estudiantil.  26.0  Hombre  Eventual
# 2                                     NaN   NaN     NaN       NaN
